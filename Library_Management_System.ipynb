# %%
# ==========================================
#       LIBRARY MANAGEMENT SYSTEM
# ==========================================

books = []


# Add a book
def add_book():
    print("\n========== ADD BOOK ==========")

    book_id = input("Enter book ID: ")
    title = input("Enter book title: ")
    author = input("Enter author name: ")

    book = {
        "id": book_id,
        "title": title,
        "author": author,
        "status": "Available"
    }

    books.append(book)

    print("\nBook added successfully!")


# View all books
def view_books():
    print("\n========== ALL BOOKS ==========")

    if len(books) == 0:
        print("No books available.")
        return

    for book in books:
        print("------------------------------")
        print("Book ID :", book["id"])
        print("Title   :", book["title"])
        print("Author  :", book["author"])
        print("Status  :", book["status"])


# Search for a book
def search_book():
    print("\n========== SEARCH BOOK ==========")

    search = input("Enter book title: ").lower()

    found = False

    for book in books:

        if search in book["title"].lower():
            print("\nBook Found!")
            print("Book ID :", book["id"])
            print("Title   :", book["title"])
            print("Author  :", book["author"])
            print("Status  :", book["status"])

            found = True

    if not found:
        print("\nBook not found.")


# Issue a book
def issue_book():
    print("\n========== ISSUE BOOK ==========")

    book_id = input("Enter book ID to issue: ")

    for book in books:

        if book["id"] == book_id:

            if book["status"] == "Available":
                book["status"] = "Issued"
                print("\nBook issued successfully!")
            else:
                print("\nBook is already issued.")

            return

    print("\nBook ID not found.")


# Return a book
def return_book():
    print("\n========== RETURN BOOK ==========")

    book_id = input("Enter book ID to return: ")

    for book in books:

        if book["id"] == book_id:

            if book["status"] == "Issued":
                book["status"] = "Available"
                print("\nBook returned successfully!")
            else:
                print("\nThis book was not issued.")

            return

    print("\nBook ID not found.")


# Main program
def main():

    while True:

        print("\n================================")
        print("    LIBRARY MANAGEMENT SYSTEM")
        print("================================")

        print("1. Add Book")
        print("2. View Books")
        print("3. Search Book")
        print("4. Issue Book")
        print("5. Return Book")
        print("6. Exit")

        choice = input("\nEnter your choice: ")

        if choice == "1":
            add_book()

        elif choice == "2":
            view_books()

        elif choice == "3":
            search_book()

        elif choice == "4":
            issue_book()

        elif choice == "5":
            return_book()

        elif choice == "6":
            print("\nThank you for using the Library Management System!")
            break

        else:
            print("\nInvalid choice. Please try again.")


# Start the program
main()
# Out:
# ================================
#     LIBRARY MANAGEMENT SYSTEM
# ================================
# 1. Add Book
# 2. View Books
# 3. Search Book
# 4. Issue Book
# 5. Return Book
# 6. Exit
#
# Enter your choice: 1
#
# ========== ADD BOOK ==========
# Enter book ID: CS001
# Enter book title: Data Structures
# Enter author name: Kashi viswanath
#
# Book added successfully!
#
# ================================
#     LIBRARY MANAGEMENT SYSTEM
# ================================
# 1. Add Book
# 2. View Books
# 3. Search Book
# 4. Issue Book
# 5. Return Book
# 6. Exit
#
# Enter your choice: 2
#
# ========== ALL BOOKS ==========
# ------------------------------
# Book ID : CS001
# Title   : Data Structures
# Author  : Kashi viswanath
# Status  : Available
#
# ================================
#     LIBRARY MANAGEMENT SYSTEM
# ================================
# 1. Add Book
# 2. View Books
# 3. Search Book
# 4. Issue Book
# 5. Return Book
# 6. Exit
#
# Enter your choice: 1
#
# ========== ADD BOOK ==========
# Enter book ID: CS002
# Enter book title: compiler design
# Enter author name: mcgrawhill
#
# Book added successfully!
#
# ================================
#     LIBRARY MANAGEMENT SYSTEM
# ================================
# 1. Add Book
# 2. View Books
# 3. Search Book
# 4. Issue Book
# 5. Return Book
# 6. Exit
#
# Enter your choice: 4
#
# ========== ISSUE BOOK ==========
# Enter book ID to issue: CS001
#
# Book issued successfully!
#
# ================================
#     LIBRARY MANAGEMENT SYSTEM
# ================================
# 1. Add Book
# 2. View Books
# 3. Search Book
# 4. Issue Book
# 5. Return Book
# 6. Exit
#
# Enter your choice: 5
#
# ========== RETURN BOOK ==========
# Enter book ID to return: CS001
#
# Book returned successfully!
#
# ================================
#     LIBRARY MANAGEMENT SYSTEM
# ================================
# 1. Add Book
# 2. View Books
# 3. Search Book
# 4. Issue Book
# 5. Return Book
# 6. Exit
#
# Enter your choice: 6
#
# Thank you for using the Library Management System!
