# %%
# ==========================================
#          PYTHON BILLING SYSTEM
# ==========================================

print("====================================")
print("         PYTHON BILLING SYSTEM")
print("====================================")

# Customer details
customer_name = input("Enter customer name: ")

# Store products
items = []

while True:

    print("\n--- Add Product ---")

    product_name = input("Enter product name: ")

    try:
        quantity = int(input("Enter quantity: "))
        price = float(input("Enter price: ₹"))
    except ValueError:
        print("Please enter valid quantity and price.")
        continue

    total = quantity * price

    items.append({
        "name": product_name,
        "quantity": quantity,
        "price": price,
        "total": total
    })

    print("Product added successfully!")

    choice = input("\nDo you want to add another product? (yes/no): ")

    if choice.lower() != "yes":
        break


# Calculate subtotal
subtotal = 0

for item in items:
    subtotal += item["total"]


# Discount
if subtotal >= 5000:
    discount = subtotal * 0.10
elif subtotal >= 2000:
    discount = subtotal * 0.05
else:
    discount = 0


# Final amount
final_amount = subtotal - discount


# ==========================================
#              FINAL BILL
# ==========================================

print("\n\n")
print("==============================================")
print("              FINAL BILL")
print("==============================================")

print("Customer Name:", customer_name)

print("----------------------------------------------")
print(f"{'Product':15} {'Qty':5} {'Price':10} {'Total':10}")
print("----------------------------------------------")

for item in items:
    print(
        f"{item['name']:15} "
        f"{item['quantity']:5} "
        f"₹{item['price']:8.2f} "
        f"₹{item['total']:8.2f}"
    )

print("----------------------------------------------")

print(f"Subtotal        : ₹{subtotal:.2f}")
print(f"Discount        : ₹{discount:.2f}")
print(f"Final Amount    : ₹{final_amount:.2f}")

print("==============================================")
print("          Thank You! Visit Again!")
print("==============================================")
# Out:
# ====================================
#          PYTHON BILLING SYSTEM
# ====================================
# Enter customer name: aishu
#
# --- Add Product ---
# Enter product name: ponds cream
# Enter quantity: 2
# Enter price: ₹120
# Product added successfully!
#
# Do you want to add another product? (yes/no): yes
#
# --- Add Product ---
# Enter product name: icecream
# Enter quantity: 3
# Enter price: ₹250
# Product added successfully!
#
# Do you want to add another product? (yes/no): no
#
#
#
# ==============================================
#               FINAL BILL
# ==============================================
# Customer Name: aishu
# ----------------------------------------------
# Product         Qty   Price      Total
# ----------------------------------------------
# ponds cream         2 ₹  120.00 ₹  240.00
# icecream            3 ₹  250.00 ₹  750.00
# ----------------------------------------------
# Subtotal        : ₹990.00
# Discount        : ₹0.00
# Final Amount    : ₹990.00
# ==============================================
#           Thank You! Visit Again!
# ==============================================
