# %%
# Contact Management System

contacts = {}

while True:
    print("\n1. Add Contact")
    print("2. View Contacts")
    print("3. Search Contact")
    print("4. Delete Contact")
    print("5. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        name = input("Enter name: ")
        phone = input("Enter phone number: ")
        contacts[name] = phone
        print("Contact added successfully")

    elif choice == 2:
        for name, phone in contacts.items():
            print(name, ":", phone)

    elif choice == 3:
        name = input("Enter name to search: ")

        if name in contacts:
            print("Phone:", contacts[name])
        else:
            print("Contact not found")

    elif choice == 4:
        name = input("Enter name to delete: ")

        if name in contacts:
            del contacts[name]
            print("Contact deleted")
        else:
            print("Contact not found")

    elif choice == 5:
        print("Thank you")
        break

    else:
        print("Invalid choice")
# Out:
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Delete Contact
# 5. Exit
# Enter your choice: 1
# Enter name: manoj
# Enter phone number: 9865456789
# Contact added successfully
#
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Delete Contact
# 5. Exit
# Enter your choice: 1
# Enter name: gousia
# Enter phone number: 8639628859
# Contact added successfully
#
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Delete Contact
# 5. Exit
# Enter your choice: 2
# manoj : 9865456789
# gousia : 8639628859
#
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Delete Contact
# 5. Exit
# Enter your choice: 4
# Enter name to delete: gousia
# Contact deleted
#
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Delete Contact
# 5. Exit
# Enter your choice: 2
# manoj : 9865456789
#
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Delete Contact
# 5. Exit
# Enter your choice: 5
