# %% [markdown]
# <a href="https://colab.research.google.com/github/ghousia2123-alt/python_mini-projects./blob/main/INVENTORY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
inventory = {
    "Pen": 20,
    "Notebook": 10,
    "Pencil": 15
}

print("Current Inventory:")
print(inventory)

item = input("Enter item name: ")

if item in inventory:
    quantity = int(input("Enter quantity to sell: "))

    if quantity <= inventory[item]:
        inventory[item] = inventory[item] - quantity
        print("Sale completed successfully.")
        print("Remaining", item, "stock:", inventory[item])
    else:
        print("Not enough stock.")
else:
    print("Item not found.")

print("Updated Inventory:")
print(inventory)
# Out:
# Current Inventory:
# {'Pen': 20, 'Notebook': 10, 'Pencil': 15}
# Enter item name: Pencil
# Enter quantity to sell: 1
# Sale completed successfully.
# Remaining Pencil stock: 14
# Updated Inventory:
# {'Pen': 20, 'Notebook': 10, 'Pencil': 14}
