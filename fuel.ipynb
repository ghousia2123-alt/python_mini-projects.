# %% [markdown]
# <a href="https://colab.research.google.com/github/ghousia2123-alt/python_mini-projects./blob/main/fuel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
distance = float(input("Enter distance in km: "))
mileage = float(input("Enter vehicle mileage (km/l): "))
fuel_price = float(input("Enter fuel price per litre: "))

fuel_needed = distance / mileage
total_cost = fuel_needed * fuel_price

print("Fuel Needed =", round(fuel_needed, 2), "litres")
print("Total Fuel Cost =", round(total_cost, 2))
# Out:
# Enter distance in km: 15
# Enter vehicle mileage (km/l): 5
# Enter fuel price per litre: 85
# Fuel Needed = 3.0 litres
# Total Fuel Cost = 255.0
