# %%
# Quiz Game

score = 0

print("Welcome to the Quiz Game!")

answer = input("1. What is the capital of India? ")

if answer.lower() == "delhi":
    print("Correct!")
    score += 1
else:
    print("Wrong!")

answer = input("2. How many days are there in a week? ")

if answer == "7":
    print("Correct!")
    score += 1
else:
    print("Wrong!")

answer = input("3. Which language are we learning? ")

if answer.lower() == "python":
    print("Correct!")
    score += 1
else:
    print("Wrong!")

print("\nYour score is:", score, "/ 3")
# Out:
# Welcome to the Quiz Game!
# 1. What is the capital of India? delhi
# Correct!
# 2. How many days are there in a week? 7
# Correct!
# 3. Which language are we learning? python
# Correct!
#
# Your score is: 3 / 3
